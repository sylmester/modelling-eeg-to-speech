# %%
import sys
sys.path.insert(0, '../..')
from dependencies import *
from constants import *
from paths import *
import helper_functions

# %% [markdown]
# # Save Audio and Preprocessed Data
# This script downloads the audio files and preprocessed data from the links provided in the README and saves them to their respective destinations.

# %%
# Function to download and extract zip files
def download_and_extract(url, zip_path, extract_to):
    print(f'Downloading from {url}...')
    response = requests.get(url, stream=True)
    with open(zip_path, 'wb') as f:
        shutil.copyfileobj(response.raw, f)
    print(f'Downloaded to {zip_path}')
    
    print(f'Extracting {zip_path} to {extract_to}...')
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    print(f'Extracted to {extract_to}')

# %%
# Define temporary download paths
TEMP_DIR = Path('temp_downloads')
TEMP_DIR.mkdir(exist_ok=True)
AUDIO_ZIP = TEMP_DIR / 'AUDIO.zip'
DATA_PREPROC_ZIP = TEMP_DIR / 'DATA_preproc.zip'

# Ensure destination directories exist
FUGLSANG_STIMULUS_DIR.mkdir(parents=True, exist_ok=True)
FUGLSANG_DATA_PREPROC.mkdir(parents=True, exist_ok=True)

# Download and extract audio files
download_and_extract(AUDIO_URL, AUDIO_ZIP, FUGLSANG_STIMULUS_DIR) # 300 MB

# Download and extract preprocessed data files
download_and_extract(DATA_PREPROC_URL, DATA_PREPROC_ZIP, FUGLSANG_DATA_PREPROC) # 1.8 GB

# Clean up temporary files
shutil.rmtree(TEMP_DIR)
print('Temporary files cleaned up.')
# Out:
# Downloading from https://zenodo.org/record/1199011/files/AUDIO.zip...
# Downloaded to temp_downloads/AUDIO.zip
# Extracting temp_downloads/AUDIO.zip to /Users/sylvestereley/Data/modelling-eeg-to-speech/fuglsang/stimuli...
# Extracted to /Users/sylvestereley/Data/modelling-eeg-to-speech/fuglsang/stimuli
# Downloading from https://zenodo.org/record/1199011/files/DATA_preproc.zip...
# Downloaded to temp_downloads/DATA_preproc.zip
# Extracting temp_downloads/DATA_preproc.zip to /Users/sylvestereley/Data/modelling-eeg-to-speech/fuglsang/data_preprocessed...
# Extracted to /Users/sylvestereley/Data/modelling-eeg-to-speech/fuglsang/data_preprocessed
# Temporary files cleaned up.
