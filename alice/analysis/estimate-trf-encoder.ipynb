# %%
import sys
sys.path.insert(0, '../..')
from dependencies import *
from constants import *
from paths import *
import helper_functions

# %%
SUBJECTS = helper_functions.alice_get_subjects()
subject_model_predictors = eelbrain.load.unpickle(ALICE_PREDICTOR_DIR / f'~concatenated_predictors.pickle')
models = helper_functions.alice_get_models()

print(models)
# Out:
# {'envelope_log': [[<NDVar 'envelope_log': 5864 time>, <NDVar 'envelope_log': 6195 time>, <NDVar 'envelope_log': 6436 time>, <NDVar 'envelope_log': 7109 time>, <NDVar 'envelope_log': 6738 time>, <NDVar 'envelope_log': 6488 time>, <NDVar 'envelope_log': 6400 time>, <NDVar 'envelope_log': 5841 time>, <NDVar 'envelope_log': 5833 time>, <NDVar 'envelope_log': 6237 time>, <NDVar 'envelope_log': 5727 time>, <NDVar 'envelope_log': 4809 time>]], 'envelope_onset': [[<NDVar 'envelope_onset': 5864 time>, <NDVar 'envelope_onset': 6195 time>, <NDVar 'envelope_onset': 6436 time>, <NDVar 'envelope_onset': 7109 time>, <NDVar 'envelope_onset': 6738 time>, <NDVar 'envelope_onset': 6488 time>, <NDVar 'envelope_onset': 6400 time>, <NDVar 'envelope_onset': 5841 time>, <NDVar 'envelope_onset': 5833 time>, <NDVar 'envelope_onset': 6237 time>, <NDVar 'envelope_onset': 5727 time>, <NDVar 'envelope_onset': 4809 time>]], 'envelope_log_onset': [[<NDVar 'envelope_log': 5864 time>, <NDVar 'envelope_log': 6195 time>, <NDVar 'envelope_log': 6436 time>, <NDVar 'envelope_log': 7109 time>, <NDVar 'envelope_log': 6738 time>, <NDVar 'envelope_log': 6488 time>, <NDVar 'envelope_log': 6400 time>, <NDVar 'envelope_log': 5841 time>, <NDVar 'envelope_log': 5833 time>, <NDVar 'envelope_log': 6237 time>, <NDVar 'envelope_log': 5727 time>, <NDVar 'envelope_log': 4809 time>], [<NDVar 'envelope_onset': 5864 time>, <NDVar 'envelope_onset': 6195 time>, <NDVar 'envelope_onset': 6436 time>, <NDVar 'envelope_onset': 7109 time>, <NDVar 'envelope_onset': 6738 time>, <NDVar 'envelope_onset': 6488 time>, <NDVar 'envelope_onset': 6400 time>, <NDVar 'envelope_onset': 5841 time>, <NDVar 'envelope_onset': 5833 time>, <NDVar 'envelope_onset': 6237 time>, <NDVar 'envelope_onset': 5727 time>, <NDVar 'envelope_onset': 4809 time>]]}

# %%
# ESTIMATE TRF

#trfs = []
for subject in SUBJECTS:
    # ————————————————————————————————————————————————————————————————————————————————————————————————
    # Make save directory
    subject_trf_dir = ALICE_TRF_DIR / subject
    subject_trf_dir.mkdir(exist_ok=True)
    trf_paths = {model: subject_trf_dir / f'{subject} {model}.pickle' for model in models}
    # Skip this subject if all files already exist
    #if all(path.exists() for path in trf_paths.values()): 
        #continue

    # ————————————————————————————————————————————————————————————————————————————————————————————————
    # Load eeg
    eeg_concatenated = eelbrain.load.unpickle(ALICE_EEG_DIR / subject / f'{subject}concatenated_eeg.pickle')
    print('——————————————————————————————')
    print(f'{subject} eeg extracted')
    
    for model, predictors in models.items():
        path = trf_paths[model]

        # ————————————————————————————————————————————————————————————————————————————————————————————————
        # Skip if the file already exists
        #'''
        skip = False
        if path.exists():
            try:
                existing_trf = eelbrain.load.unpickle(path)
                if existing_trf is not None:
                    print(f"TRF for {subject} ~ {model} already exists, skipping...\n")
                    skip = True
            except Exception as e:
                print(f"Warning: existing TRF file for {subject} ~ {model} is corrupted or unreadable, will recompute. ({e})")
        if skip:
            continue
        print(f"Estimating: {subject} ~ {model}")
        #'''
        # ————————————————————————————————————————————————————————————————————————————————————————————————
        # Fit the mTRF
        predictors_concatenated = subject_model_predictors[subject][model]
        print('now boosting')
        trf = eelbrain.boosting(eeg_concatenated, predictors_concatenated, -0.100, 1.000, 
                                error='l1', basis=0.050, partitions=5, test=1, selective_stopping=True)
        #trfs.append((model, predictors, trf))

        # ————————————————————————————————————————————————————————————————————————————————————————————————
        # Save in directory
        eelbrain.save.pickle(trf, path)
        print(f'TRF for {model} complete')
# Out:
# ——————————————————————————————
# S01 eeg extracted
# TRF for S01 ~ envelope_log already exists, skipping...
#
# TRF for S01 ~ envelope_onset already exists, skipping...
#
# TRF for S01 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S03 eeg extracted
# TRF for S03 ~ envelope_log already exists, skipping...
#
# TRF for S03 ~ envelope_onset already exists, skipping...
#
# TRF for S03 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S04 eeg extracted
# TRF for S04 ~ envelope_log already exists, skipping...
#
# TRF for S04 ~ envelope_onset already exists, skipping...
#
# TRF for S04 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S05 eeg extracted
# TRF for S05 ~ envelope_log already exists, skipping...
#
# TRF for S05 ~ envelope_onset already exists, skipping...
#
# TRF for S05 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S06 eeg extracted
# TRF for S06 ~ envelope_log already exists, skipping...
#
# TRF for S06 ~ envelope_onset already exists, skipping...
#
# TRF for S06 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S08 eeg extracted
# TRF for S08 ~ envelope_log already exists, skipping...
#
# TRF for S08 ~ envelope_onset already exists, skipping...
#
# TRF for S08 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S10 eeg extracted
# TRF for S10 ~ envelope_log already exists, skipping...
#
# TRF for S10 ~ envelope_onset already exists, skipping...
#
# TRF for S10 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S11 eeg extracted
# TRF for S11 ~ envelope_log already exists, skipping...
#
# TRF for S11 ~ envelope_onset already exists, skipping...
#
# TRF for S11 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S12 eeg extracted
# TRF for S12 ~ envelope_log already exists, skipping...
#
# TRF for S12 ~ envelope_onset already exists, skipping...
#
# TRF for S12 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S13 eeg extracted
# TRF for S13 ~ envelope_log already exists, skipping...
#
# TRF for S13 ~ envelope_onset already exists, skipping...
#
# TRF for S13 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S14 eeg extracted
# TRF for S14 ~ envelope_log already exists, skipping...
#
# TRF for S14 ~ envelope_onset already exists, skipping...
#
# TRF for S14 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S15 eeg extracted
# TRF for S15 ~ envelope_log already exists, skipping...
#
# TRF for S15 ~ envelope_onset already exists, skipping...
#
# TRF for S15 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S16 eeg extracted
# TRF for S16 ~ envelope_log already exists, skipping...
#
# TRF for S16 ~ envelope_onset already exists, skipping...
#
# TRF for S16 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S17 eeg extracted
# TRF for S17 ~ envelope_log already exists, skipping...
#
# TRF for S17 ~ envelope_onset already exists, skipping...
#
# TRF for S17 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S18 eeg extracted
# TRF for S18 ~ envelope_log already exists, skipping...
#
# TRF for S18 ~ envelope_onset already exists, skipping...
#
# TRF for S18 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S19 eeg extracted
# TRF for S19 ~ envelope_log already exists, skipping...
#
# TRF for S19 ~ envelope_onset already exists, skipping...
#
# TRF for S19 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S20 eeg extracted
# TRF for S20 ~ envelope_log already exists, skipping...
#
# TRF for S20 ~ envelope_onset already exists, skipping...
#
# TRF for S20 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S21 eeg extracted
# TRF for S21 ~ envelope_log already exists, skipping...
#
# TRF for S21 ~ envelope_onset already exists, skipping...
#
# TRF for S21 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S22 eeg extracted
# TRF for S22 ~ envelope_log already exists, skipping...
#
# TRF for S22 ~ envelope_onset already exists, skipping...
#
# TRF for S22 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S25 eeg extracted
# TRF for S25 ~ envelope_log already exists, skipping...
#
# TRF for S25 ~ envelope_onset already exists, skipping...
#
# TRF for S25 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S26 eeg extracted
# TRF for S26 ~ envelope_log already exists, skipping...
#
# TRF for S26 ~ envelope_onset already exists, skipping...
#
# TRF for S26 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S34 eeg extracted
# TRF for S34 ~ envelope_log already exists, skipping...
#
# TRF for S34 ~ envelope_onset already exists, skipping...
#
# TRF for S34 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S35 eeg extracted
# TRF for S35 ~ envelope_log already exists, skipping...
#
# TRF for S35 ~ envelope_onset already exists, skipping...
#
# TRF for S35 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S36 eeg extracted
# TRF for S36 ~ envelope_log already exists, skipping...
#
# TRF for S36 ~ envelope_onset already exists, skipping...
#
# TRF for S36 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S37 eeg extracted
# TRF for S37 ~ envelope_log already exists, skipping...
#
# TRF for S37 ~ envelope_onset already exists, skipping...
#
# TRF for S37 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S38 eeg extracted
# TRF for S38 ~ envelope_log already exists, skipping...
#
# TRF for S38 ~ envelope_onset already exists, skipping...
#
# TRF for S38 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S39 eeg extracted
# TRF for S39 ~ envelope_log already exists, skipping...
#
# TRF for S39 ~ envelope_onset already exists, skipping...
#
# TRF for S39 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S40 eeg extracted
# TRF for S40 ~ envelope_log already exists, skipping...
#
# TRF for S40 ~ envelope_onset already exists, skipping...
#
# TRF for S40 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S41 eeg extracted
# TRF for S41 ~ envelope_log already exists, skipping...
#
# TRF for S41 ~ envelope_onset already exists, skipping...
#
# TRF for S41 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S42 eeg extracted
# TRF for S42 ~ envelope_log already exists, skipping...
#
# TRF for S42 ~ envelope_onset already exists, skipping...
#
# TRF for S42 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S44 eeg extracted
# TRF for S44 ~ envelope_log already exists, skipping...
#
# TRF for S44 ~ envelope_onset already exists, skipping...
#
# TRF for S44 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S45 eeg extracted
# TRF for S45 ~ envelope_log already exists, skipping...
#
# TRF for S45 ~ envelope_onset already exists, skipping...
#
# TRF for S45 ~ envelope_log_onset already exists, skipping...
#
# ——————————————————————————————
# S48 eeg extracted
# TRF for S48 ~ envelope_log already exists, skipping...
#
# TRF for S48 ~ envelope_onset already exists, skipping...
#
# TRF for S48 ~ envelope_log_onset already exists, skipping...
