# %%
# DEPENDENCIES

import sys
sys.path.insert(0, '../../..')
from dependencies import *
from constants import *
from paths import *
import helper_functions

# %%
# SET-UP
SUBJECTS = helper_functions.alice_get_subjects()
ENVELOPES_LOG = eelbrain.load.unpickle(ALICE_PROCESSED_PREDICTOR_DIR / f'~processed_envelopes-log.pickle')
STIMULI = [str(i) for i in range(1, 13)]
DURATIONS = helper_functions.alice_get_durations(ENVELOPES_LOG, STIMULI)

LOW_FREQUENCY = 0.5
HIGH_FREQUENCY = 20

# Define models
trf_types = [
    # Single predictors
    (PREDICTOR_TYPE.ENVELOPE,       ATTENTION_TYPE.SINGLE, MODEL_TYPE.BACKWARD),
    (PREDICTOR_TYPE.ENVELOPE_ONSET, ATTENTION_TYPE.SINGLE, MODEL_TYPE.BACKWARD),

    # Multiple predictors
    #([PREDICTOR_TYPE.ENVELOPE, PREDICTOR_TYPE.ENVELOPE_ONSET], ATTENTION_TYPE.SINGLE, MODEL_TYPE.FORWARD, False),
]

# %%
# LOAD EEG DATA DOWNSAMPLED TO 64 HZ

# Iterate over the EEG of every subject
for subject in SUBJECTS:
    print('——————————————————————————————')
    print(f"Processing Subject {subject}")
    
    # Extract the raw files
    raw = mne.io.read_raw(ALICE_EEG_DIR / subject / f'{subject}_alice-raw.fif', preload=True)
    # Filter the raw data to the desired band
    raw.filter(LOW_FREQUENCY, HIGH_FREQUENCY, n_jobs=1)
    # Interpolate bad channels
    raw.interpolate_bads() # <-- No bad filters so commented out

    # Load the events embeded in the raw file
    events = eelbrain.load.fiff.events(raw)

    # Not all subjects have all trials; determine which stimuli are present
    trial_indexes = [STIMULI.index(stimulus) for stimulus in events['event']]
    # Extract the EEG data segments corresponding to the stimuli
    trial_durations = [DURATIONS[i] for i in trial_indexes]
    # Load the EEG with corresponding epochs
    eeg = eelbrain.load.fiff.variable_length_epochs(events, 
                                                    -0.100, 
                                                    trial_durations) # <-- Separates by events, adds 100ms pre-stimulus, no decimation anymore
    # Since trials are of unequal length, we will concatenate them for the TRF estimation.
    eeg_concatenated = eelbrain.concatenate(eeg)
    #print(eeg_concatenated)

    # Resample to 64 Hz <-- Most important change for this code snippet
    eeg_resampled = eelbrain.resample(eeg_concatenated, 64)
    #print(eeg_resampled.time.tstep)

    # ————————————————————————————————————————————————————————————————————————————————————————————————
    # Save pickle
    eelbrain.save.pickle(eeg_resampled, ALICE_EEG_DIR / subject / f'{subject} 64hz_concatenated_eeg.pickle')

print('\nProcess Completed! \n:)')
# Out:
# ——————————————————————————————
# Processing Subject S01
# ——————————————————————————————
# Processing Subject S03
# ——————————————————————————————
# Processing Subject S04
# ——————————————————————————————
# Processing Subject S05
# ——————————————————————————————
# Processing Subject S06
# ——————————————————————————————
# Processing Subject S08
# ——————————————————————————————
# Processing Subject S10
# ——————————————————————————————
# Processing Subject S11
# ——————————————————————————————
# Processing Subject S12
# ——————————————————————————————
# Processing Subject S13
# ——————————————————————————————
# Processing Subject S14
# ——————————————————————————————
# Processing Subject S15
# /var/folders/q5/dlf_55750jq9b22jkpyf6c940000gn/T/ipykernel_43331/3544335462.py:13: RuntimeWarning: No bad channels to interpolate. Doing nothing...
#   raw.interpolate_bads() # <-- No bad filters so commented out
# ——————————————————————————————
# Processing Subject S16
# ——————————————————————————————
# Processing Subject S17
# ——————————————————————————————
# Processing Subject S18
# ——————————————————————————————
# Processing Subject S19
# ——————————————————————————————
# Processing Subject S20
# ——————————————————————————————
# Processing Subject S21
# ——————————————————————————————
# Processing Subject S22
# ——————————————————————————————
# Processing Subject S25
# ——————————————————————————————
# Processing Subject S26
# ——————————————————————————————
# Processing Subject S34
# ——————————————————————————————
# Processing Subject S35
# ——————————————————————————————
# Processing Subject S36
# ——————————————————————————————
# Processing Subject S37
# ——————————————————————————————
# Processing Subject S38
# ——————————————————————————————
# Processing Subject S39
# ——————————————————————————————
# Processing Subject S40
# ——————————————————————————————
# Processing Subject S41
# ——————————————————————————————
# Processing Subject S42
# ——————————————————————————————
# Processing Subject S44
# ——————————————————————————————
# Processing Subject S45
# ——————————————————————————————
# Processing Subject S48
#
# Process Completed!
# :)

# %%
# LOAD PREDICTORS DOWNSAMPLED TO 64 HZ

# Log
envelopes_log = [eelbrain.load.unpickle(ALICE_PREDICTOR_DIR / f'{stimulus}~envelope-log.pickle') for stimulus in STIMULI]
envelopes_log = [eelbrain.resample(x, 64) for x in envelopes_log]  # ← same as EEG
envelopes_log = [eelbrain.pad(x, tstart=-0.100, tstop=x.time.tstop+1, name='envelope_log') for x in envelopes_log]
envelopes_log = [eelbrain.filter_data(x, LOW_FREQUENCY, HIGH_FREQUENCY) for x in envelopes_log]

# Onset
envelopes_onset = [eelbrain.load.unpickle(ALICE_PREDICTOR_DIR / f'{stimulus}~envelope-onset.pickle') for stimulus in STIMULI]
envelopes_onset = [eelbrain.resample(x, 64) for x in envelopes_onset]  # ← same as EEG
envelopes_onset = [eelbrain.pad(x, tstart=-0.100, tstop=x.time.tstop+1, name='envelope_onset') for x in envelopes_onset]
envelopes_onset = [eelbrain.filter_data(x, LOW_FREQUENCY, HIGH_FREQUENCY) for x in envelopes_onset]

# Concatenate for the different trials
for subject in SUBJECTS:
    raw = mne.io.read_raw(ALICE_EEG_DIR / subject / f'{subject}_alice-raw.fif', preload=True)
    events = eelbrain.load.fiff.events(raw)
    trial_indexes = [STIMULI.index(stimulus) for stimulus in events['event']]
    trial_durations = [DURATIONS[i] for i in trial_indexes]

    # Get per-trial EEG lengths to match predictors against
    eeg_epochs = eelbrain.load.fiff.variable_length_epochs(events, -0.100, trial_durations)
    eeg_epochs_resampled = [eelbrain.resample(epoch, 64) for epoch in eeg_epochs]


    # 64 hz sample causes length mismatch in events ending exactly in numbers divisible by 64, adding or removing +- 1 sample
    # We introduce correction function to match the samples directly
    def match_length(pred, eeg_epoch):
        n_diff = pred.time.nsamples - eeg_epoch.time.nsamples
        if n_diff > 0:
            return pred.sub(time=(pred.time.tmin, pred.time.tmin + eeg_epoch.time.nsamples / 64))
        return pred

    envelopes_log_concat = eelbrain.concatenate([match_length(envelopes_log[idx], epoch) 
                                                  for idx, epoch in zip(trial_indexes, eeg_epochs_resampled)])
    envelopes_onset_concat = eelbrain.concatenate([match_length(envelopes_onset[idx], epoch) 
                                                    for idx, epoch in zip(trial_indexes, eeg_epochs_resampled)])
    
    # ————————————————————————————————————————————————————————————————————————————————————————————————
    # Save pickles

    eelbrain.save.pickle(envelopes_log_concat, 
                            ALICE_PROCESSED_PREDICTOR_DIR / f'{subject} 64hz-processed-envelope_log.pickle') # <-- This is referred to as gammatone-1 in document
    eelbrain.save.pickle(envelopes_onset_concat, 
                            ALICE_PROCESSED_PREDICTOR_DIR / f'{subject} 64hz-processed-envelope_onset.pickle') # <-- This is referred to as gammatone-on-1 in document
    
print('\nProcess Completed! \n:)')
# Out:
# Process Completed!
# :)

# %%
# ESTIMATE ALIGNED BACKWARD MODEL TRFS WITH 64HZ DATA

# Iterative loop to estimate every decoder TRF per-subject
for subject in SUBJECTS:
    # ————————————————————————————————————————————————————————————————————————————————————————————————
    # Load eeg
    eeg = eelbrain.load.unpickle(ALICE_EEG_DIR / subject / f'{subject} 64hz_concatenated_eeg.pickle')
    print('——————————————————————————————')
    print(f'{subject} eeg extracted')

    for type in trf_types: 
        # ————————————————————————————————————————————————————————————————————————————————————————————————
        # Get the model name
        p, a, w = type
        model = helper_functions.get_trf_model_name(DATASET_TYPE.ALICE, *type)

        save_path = ALICE_TRF_DIR / subject / f'{subject} 64hz-{model}.pickle'
        
        if save_path.exists():
            print(f" {save_path} Already exists, skipping.")
            continue

        if isinstance(p, PREDICTOR_TYPE):
            predictor_type = helper_functions.map_predictor_name(p, DATASET_TYPE.ALICE)
            predictors = eelbrain.load.unpickle(ALICE_PROCESSED_PREDICTOR_DIR / f'{subject} 64hz-processed-{predictor_type}.pickle')
        else:
            predictors = []
            for _ in p:
                predictor_type = helper_functions.map_predictor_name(_, DATASET_TYPE.ALICE) 
                predictors.append(eelbrain.load.unpickle(ALICE_PROCESSED_PREDICTOR_DIR / f'{subject} 64hz-processed-{predictor_type}.pickle'))

        trf = eelbrain.boosting(predictors, eeg, -1.000, 0.100, 
                                error='l1', basis=0.050, partitions=5, test=1, selective_stopping=True)

        # ————————————————————————————————————————————————————————————————————————————————————————————————
        # Save in directory
        eelbrain.save.pickle(trf, save_path)
        print(f'TRF for {model} complete')
    
print('\nProcess Completed! \n:)')
# Out:
# ——————————————————————————————
# S01 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S01/S01 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S01/S01 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S03 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S03/S03 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S03/S03 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S04 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S04/S04 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S04/S04 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S05 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S05/S05 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S05/S05 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S06 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S06/S06 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S06/S06 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S08 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S08/S08 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S08/S08 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S10 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S10/S10 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S10/S10 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S11 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S11/S11 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S11/S11 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S12 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S12/S12 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S12/S12 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S13 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S13/S13 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S13/S13 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S14 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S14/S14 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S14/S14 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S15 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S15/S15 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S15/S15 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S16 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S16/S16 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S16/S16 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S17 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S17/S17 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S17/S17 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S18 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S18/S18 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S18/S18 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S19 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S19/S19 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S19/S19 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S20 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S20/S20 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S20/S20 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S21 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S21/S21 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S21/S21 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S22 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S22/S22 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S22/S22 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S25 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S25/S25 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S25/S25 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S26 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S26/S26 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S26/S26 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S34 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S34/S34 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S34/S34 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S35 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S35/S35 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S35/S35 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S36 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S36/S36 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S36/S36 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S37 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S37/S37 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S37/S37 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S38 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S38/S38 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S38/S38 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S39 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S39/S39 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S39/S39 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S40 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S40/S40 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S40/S40 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S41 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S41/S41 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S41/S41 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S42 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S42/S42 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S42/S42 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S44 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S44/S44 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S44/S44 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S45 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S45/S45 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S45/S45 64hz-decoder-envelope_onset.pickle Already exists, skipping.
# ——————————————————————————————
# S48 eeg extracted
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S48/S48 64hz-decoder-envelope_log.pickle Already exists, skipping.
#  /Users/sylvestereley/Data/modelling-eeg-to-speech/alice/TRFs/S48/S48 64hz-decoder-envelope_onset.pickle Already exists, skipping.
#
# Process Completed!
# :)
